# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/oyo-hotel-rooms/OYO_HOTEL_ROOMS.csv')

# %%
df.shape

# %%
df.tail(10)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.dropna(inplace = True)

# %%
df.shape

# %%
# Visualize distribution of prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=20, kde=True)
plt.title('Distribution of Prices')
plt.xlabel('Price per Night')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Highest Price is 1000**

# %%
# Visualize ratings distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'], bins=20, kde=True)
plt.title('Distribution Of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualize relationship between price and rating
plt.figure(figsize =(10,6))
sns.scatterplot(x ="Price",y = "Rating" ,data = df)
plt.title("Price Vs Rating")
plt.xlabel("Price Per Night")
plt.ylabel("Rating")

# %%
# Calculate average price and rating by location
avg_price_by_location = df.groupby('Location')['Price'].mean()
avg_rating_by_location = df.groupby('Location')['Rating'].mean()

# %%
# Visualize average price and rating by location
# Calculate average price and rating by location
avg_price_by_location = df.groupby('Location')['Price'].mean().sort_values(ascending=False).head(10)
avg_rating_by_location = df.groupby('Location')['Rating'].mean().sort_values(ascending=False).head(10)

# Visualize average price and rating by location for the top 10 locations
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_price_by_location.index, y=avg_price_by_location.values)
plt.title('Top 10 Locations: Average Price by Location')
plt.xlabel('Location')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=avg_rating_by_location.index, y=avg_rating_by_location.values)
plt.title('Top 10 Locations: Average Rating by Location')
plt.xlabel('Location')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Conclusion**
# Top 10 Locations by Average Price in Mumbai and Bangalore, And
# Top 10 Locations by Average Ratingins in Delhi, Bangalore , And kolkata
# And no clearity between price and Rating so need to improve and services in other cities including mumbai All Location.

# %% [markdown]
# ****
